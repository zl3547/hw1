# %% [markdown]
# <a href="https://colab.research.google.com/github/zl3547/hw1/blob/patch-1/BondDuration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def getBondDuration(y, face, couponRate, m, ppy = 1):
    BondPrice = 0
    pvCoupons = 0
    Coupons = face * coupon_rate / ppy
    pvCoupons_t = 0

    for i in range(1, (m*ppy)+1):
        pvCoupons += Coupons*(1+y/ppy)**-i
        pvCoupons_t += (Coupons*(1+y/ppy)**-i)*i

    BondPrice = pvCoupons+face*(1+y/ppy)**(-m*ppy)
    BondPrice_t = pvCoupons_t+(face*(1+y/ppy)**(-m*ppy))*(m*ppy)

    return BondPrice_t/BondPrice

# Test values
y = 0.03
face = 2000000
coupon_rate = 0.04
m = 10
ppy = 1

duration = getBondDuration(y, face, coupon_rate, m, ppy)
print(duration)
# Out:
# 8.508690304459574
